# %%
print("db connection successfull")

# %%
# %pip install psycopg2-binary

# %%
# %pip install psycopg2-binary

# %%
# %restart_python

# %%
import psycopg2 

conn = psycopg2.connect(host='your_host', port='your_port', database='myproject', user='postgres', password='9898')
    host="localhost",
    port="5432",
    database="myproject",
    user="postgres",
    password="9898"
)

cursor = conn.cursor()

cursor.execute("SELECT version();")

print(cursor.fetchone())

cursor.close()
conn.close()
